# %%
import pandas as pd
from pandas import json_normalize
import numpy as np
import json

# %%
load_df = pd.read_json('all_stores.json')

places_df = []
for i in range(len(load_df['places'])):
    load_df['places'][i] = json_normalize(load_df['places'][i])
    places_df.append(load_df['places'][i])

places_df = pd.concat(places_df, ignore_index=True)
places_df = places_df.drop_duplicates(subset=['_id'])
places_df = places_df.reset_index(drop=True)
places_df
# Out:
#                            _id                   name  \
# 0     6492272ea5cf7208986fd4a1   Unifirst Corporation
# 1     64d2c0cc1a6e65029aa05eb1           1213 Apparel
# 2     646e78e4257d5b67299e0169         Generation Tux
# 3     612510d85418e17cc9245add          Milk and Baby
# 4     6492271b7e3ba4281d07d135             Ocean Soul
# ...                        ...                    ...
# 2214  62cd931798b993111c81c6ad      Small Town Sports
# 2215  5dc9a0f42004860034baa294               Goodwill
# 2216  5f668148618655405b9cf83f   Cindy's Consignments
# 2217  649227400db46f4659fc341e  Dis & Dat Thrift Shop
# 2218  64d2c09b2bf3f14198ce356a               Mw23 Llc
#
#                                              categories location.type  \
# 0            [shopping-retail, apparel, clothing-store]         Point
# 1            [shopping-retail, apparel, clothing-store]         Point
# 2            [shopping-retail, apparel, clothing-store]         Point
# 3            [shopping-retail, apparel, clothing-store]         Point
# 4     [shopping-retail, apparel, accessories-store, ...         Point
# ...                                                 ...           ...
# 2214            [shopping-retail, sporting-goods-store]         Point
# 2215     [shopping-retail, thrift-or-consignment-store]         Point
# 2216     [shopping-retail, thrift-or-consignment-store]         Point
# 2217     [shopping-retail, thrift-or-consignment-store]         Point
# 2218                   [shopping-retail, tobacco-store]         Point
#
#                           location.coordinates chain.slug chain.name  \
# 0                       [-85.54013, 38.200959]        NaN        NaN
# 1                       [-85.535805, 38.20584]        NaN        NaN
# 2     [-85.55429010934739, 38.199565387667185]        NaN        NaN
# 3        [-85.554694259683, 38.20549894652019]        NaN        NaN
# 4                      [-85.550278, 38.217419]        NaN        NaN
# ...                                        ...        ...        ...
# 2214                    [-85.548869, 38.05258]        NaN        NaN
# 2215   [-85.53936955313168, 38.05410023381892]   goodwill   Goodwill
# 2216   [-85.54878303804244, 38.05653298911513]        NaN        NaN
# 2217   [-85.54934888093514, 38.04372817217552]        NaN        NaN
# 2218  [-85.54003730411537, 38.049058295641096]        NaN        NaN
#
#       chain.domain
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 2214           NaN
# 2215  goodwill.org
# 2216           NaN
# 2217           NaN
# 2218           NaN
#
# [2219 rows x 8 columns]
