# %%
import pandas as pd
from pandas import json_normalize
import numpy as np
import json

# %%
load_df = pd.read_json('all_stores.json')

places_df = []
for i in range(len(load_df['places'])):
    load_df['places'][i] = json_normalize(load_df['places'][i])
    places_df.append(load_df['places'][i])

places_df = pd.concat(places_df, ignore_index=True)
places_df = places_df.drop_duplicates(subset=['_id'])
places_df = places_df.reset_index(drop=True)
places_df
# Out:
#                            _id                   name  \
# 0     5dc9a3252004860034bb4886           Jos. A. Bank
# 1     5dc30383d7f7ed0033d7739b        Brooks Brothers
# 2     5f664553618655405b0c999d               UNTUCKit
# 3     610b19edef48a87fb957d8cf        Men's Wearhouse
# 4     610b19f42a4fba19f0a8b807        Men's Wearhouse
# ...                        ...                    ...
# 2218  62cd931798b993111c81c6ad      Small Town Sports
# 2219  5dc9a0f42004860034baa294               Goodwill
# 2220  5f668148618655405b9cf83f   Cindy's Consignments
# 2221  649227400db46f4659fc341e  Dis & Dat Thrift Shop
# 2222  64d2c09b2bf3f14198ce356a               Mw23 Llc
#
#                                              categories location.type  \
# 0     [shopping-retail, apparel, clothing-store, men...         Point
# 1     [shopping-retail, apparel, clothing-store, men...         Point
# 2     [shopping-retail, apparel, clothing-store, men...         Point
# 3     [shopping-retail, apparel, clothing-store, men...         Point
# 4     [shopping-retail, apparel, clothing-store, men...         Point
# ...                                                 ...           ...
# 2218            [shopping-retail, sporting-goods-store]         Point
# 2219     [shopping-retail, thrift-or-consignment-store]         Point
# 2220     [shopping-retail, thrift-or-consignment-store]         Point
# 2221     [shopping-retail, thrift-or-consignment-store]         Point
# 2222                   [shopping-retail, tobacco-store]         Point
#
#                           location.coordinates       chain.slug  \
# 0      [-85.57969733206755, 38.24865779225328]       jos-a-bank
# 1       [-85.60989387949492, 38.2469695800491]  brooks-brothers
# 2      [-85.61103289913419, 38.24746907539493]         untuckit
# 3     [-85.61112991115479, 38.249629690618555]   mens-wearhouse
# 4      [-85.57501727325047, 38.30866610396779]   mens-wearhouse
# ...                                        ...              ...
# 2218                    [-85.548869, 38.05258]              NaN
# 2219   [-85.53936955313168, 38.05410023381892]         goodwill
# 2220   [-85.54878303804244, 38.05653298911513]              NaN
# 2221   [-85.54934888093514, 38.04372817217552]              NaN
# 2222  [-85.54003730411537, 38.049058295641096]              NaN
#
#            chain.name        chain.domain
# 0        Jos. A. Bank         josbank.com
# 1     Brooks Brothers  brooksbrothers.com
# 2            UNTUCKit        untuckit.com
# 3     Men's Wearhouse   menswearhouse.com
# 4     Men's Wearhouse   menswearhouse.com
# ...               ...                 ...
# 2218              NaN                 NaN
# 2219         Goodwill        goodwill.org
# 2220              NaN                 NaN
# 2221              NaN                 NaN
# 2222              NaN                 NaN
#
# [2223 rows x 8 columns]
